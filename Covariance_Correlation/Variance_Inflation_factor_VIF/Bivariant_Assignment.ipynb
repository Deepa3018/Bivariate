# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# ## 1)check if all the Nan values are filled with values

# %% [markdown]
# dataset.isnull().sum()

# %%
placed=dataset.dropna()
Not_placed=dataset[dataset['status']=='Not Placed']

# %%
Not_placed
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %% [markdown]
# ## 2)There are 67 students with non placement

# %% [markdown]
# ## 3) The placement data looks random and do not specify a reason for non-placement as mixed category of students have non-placement issues

# %% [markdown]
# dataset["salary"].fillna(0,inplace=True)

# %% [markdown]
# dataset

# %% [markdown]
# dataset.isnull().sum()

# %% [markdown]
# ## 4)relation between mba_p and salary is zero correlation

# %% [markdown]
# #salary and mba_p has positive correlation of 0.1783 (17.83%)

# %%
def QuanQual(dataset):
    Quan=[]
    Qual=[]
    for ColumnName in dataset.columns:
        print(ColumnName)
        if(dataset[ColumnName].dtypes=="O"):
            #print("Qual")
            Qual.append(ColumnName)
        else:
            #print("Quan")
            Quan.append(ColumnName)
    return Quan,Qual

# %%
quan,qual=QuanQual(dataset)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
quandataset=dataset[quan]
quandataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0
# 7        8  82.00  64.00     66.00     67.0  62.14  252000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 209    210  62.00  72.00     65.00     67.0  56.49  216000.0
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0
#
# [148 rows x 7 columns]

# %%
quandataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.093480 -0.218428 -0.102250  0.041467 -0.072432  0.063764
# ssc_p    -0.093480  1.000000  0.293416  0.380657  0.317892  0.430560  0.035330
# hsc_p    -0.218428  0.293416  1.000000  0.221307  0.284672  0.329983  0.076819
# degree_p -0.102250  0.380657  0.221307  1.000000  0.217683  0.494093 -0.019272
# etest_p   0.041467  0.317892  0.284672  0.217683  1.000000  0.284143  0.178307
# mba_p    -0.072432  0.430560  0.329983  0.494093  0.284143  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# ## 5)who is getting minimum salary

# %%
dataset=pd.read_csv("Placement.csv")

# %%
df = pd.DataFrame(dataset)

# Find minimum salary
min_salary = df['salary'].min()

# Identify who gets the minimum salary
min_salary_entries = df[df['salary'] == min_salary]

# %%
min_salary
# Out:
# 200000.0

# %%
min_salary_entries
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 15      16      F  65.00  Central  75.00  Central  Commerce     69.00
# 44      45      F  77.00   Others  73.00   Others  Commerce     81.00
# 50      51      F  75.20  Central  73.20  Central   Science     68.40
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 135    136      F  72.00  Central  56.00   Others   Science     69.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0
# 15   Comm&Mgmt    Yes     72.0        Mkt&Fin  64.66  Placed  200000.0
# 44   Comm&Mgmt    Yes     89.0        Mkt&Fin  69.70  Placed  200000.0
# 50   Comm&Mgmt     No     65.0         Mkt&HR  62.98  Placed  200000.0
# 107  Comm&Mgmt     No     80.0         Mkt&HR  73.52  Placed  200000.0
# ...

# %% [markdown]
# ### Comm&Mgmt Specialisation in degree gets minimum salary

# %% [markdown]
# ## 6) Salary count more than 50000

# %%
sal_morethan50000=dataset[dataset["salary"]>500000]
sal_morethan50000

# %%
sal_morethan50000['salary'].count()
# Out:
# 3

# %% [markdown]
# ## 7)Analysis of variance between etest_p and mba_p: p<0.05, as p_value is less than 0.05 null hypothesis is rejected and alternate hypothesis is accepted

# %%
import scipy.stats as stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])

# %% [markdown]
# ## 8)comparing Scitech(degree)and Mkt&HR (specialisation) with salary (Independent(comparison of different pair with same attribute), Unpaired)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
Scitech_sal=dataset[dataset['degree_t']=='Sci&Tech']["salary"]
Mkt_HR_sal=dataset[dataset['specialisation']=='Mkt&HR']["salary"]
ttest_ind(Scitech_sal,Mkt_HR_sal)

# %% [markdown]
# ### Here comparing the salary with degree_Scitech and specialisation_MBA&HR with salary p_value is <0.05, so null hypothesis is rejected and alternate hypothesis is accepted

# %%
#Normal distribution of the salary column
import seaborn as sns
sns.distplot(dataset["salary"])
# Out:
# C:\Users\Deepa Deva\AppData\Local\Temp\ipykernel_8376\1906475609.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["salary"])
# <Axes: xlabel='salary', ylabel='Density'>

# %% [markdown]
# ## 10) Probability Density function of salary range between 700000 and 900000

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\Deepa Deva\AppData\Local\Temp\ipykernel_20680\132380739.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=288655.405, Standard Deviation=93457.452
# The area between range(700000,900000):5.377578376230696e-06
# 5.377578376230696e-06

# %% [markdown]
# ## 9)Convert normal distribution to standard deviation for salary column:

# %%
def stdNDgraph(dataset):
    import seaborn as sns
    #calculate mean and standard devaiation
    mean=dataset.mean()
    std=dataset.std()
    #for every value of mean and standard deviation calculate the z-score
    values=[i for i in dataset]
    #calculate z-score
    z_score=[((j-mean)/std) for j in values]
    #plot the graph with standard scaled values calculated using z-score
    sns.distplot(z_score,kde=True)
    sum((z_score)/len(z_score))

# %%
stdNDgraph(dataset["salary"])
# Out:
# C:\Users\Deepa Deva\AppData\Local\Temp\ipykernel_20680\4247053323.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 stdNDgraph(dataset["salary"])
#
# Cell In[64], line 12, in stdNDgraph(dataset)
#      10 #plot the graph with standard scaled values calculated using z-score
#      11 sns.distplot(z_score,kde=True)
# ---> 12 sum((z_score)/len(z_score))
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %% [markdown]
# # 11)Test the similarity b/w degree_t(Sci&Tech) with respect to etest_p & mba_p at significance level of 5%.
# # (Make the decision using Hypothesis Testing).

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
etest_p = dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
mba_p = dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
ttest_ind(etest_p, mba_p)

# %%
# Null Hypothesis = There is no similarity between degree_t(Sci&Tech) with respect to (mba_p, etest_p).
# Alternate Hypothesis = There is similarity between degree_t(Sci&Tech) with respect to (mba_p, etest_p).

# pValue=5.0277 which is not < 0.05, So, Alternate Hypothesis is Rejected. 
# Finally, The Null Hypothesis is Accepted. 
# There is no similarity between degree_t(Sci&Tech) and  (mba_p, etest_p).

# %% [markdown]
# ## 12)Test the difference between degree_t (Scitech)with respect to etest_p and mba_p and making hypothetical decision

# %%
#12) (Dependent(comparison of same pair with different attribute), Paired)

from scipy.stats import ttest_ind
dataset=dataset.dropna()
Scitech_etest_p=dataset[dataset['degree_t']=='Sci&Tech']["etest_p"]
Scitech_mba_p=dataset[dataset['degree_t']=='Sci&Tech']["mba_p"]
ttest_ind(Scitech_etest_p,Scitech_mba_p)
# Out:
# TtestResult(statistic=4.286330847883898, pvalue=5.0277529026696236e-05, df=80.0)

# %%
# H0= There is no significant interaction effect between Sci&Tech * etest_p *mba_p
# H1= There is significant interaction effect between Sci&Tech * etest_p *mba_p

#Conclusion: p_value<0.05, so null hypothesis is rejected and alternate hypothesis is accepted and so There is significant interaction effect between Sci&Tech * etest_p *mba_p

# %%
quandataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.093480 -0.218428 -0.102250  0.041467 -0.072432  0.063764
# ssc_p    -0.093480  1.000000  0.293416  0.380657  0.317892  0.430560  0.035330
# hsc_p    -0.218428  0.293416  1.000000  0.221307  0.284672  0.329983  0.076819
# degree_p -0.102250  0.380657  0.221307  1.000000  0.217683  0.494093 -0.019272
# etest_p   0.041467  0.317892  0.284672  0.217683  1.000000  0.284143  0.178307
# mba_p    -0.072432  0.430560  0.329983  0.494093  0.284143  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# ## 13 From the pair plot (Q4 above)ssc_p is highly correlated with salary

# %% [markdown]
# ## 14 Other plots

# %%
import seaborn as sns
sns.pairplot(quandataset)
# Out:
# C:\Anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
